# %%
import random
from datetime import datetime, timedelta
from typing import List, Dict, Any

NUM_STORES = 5
NUM_PRODUCTS = 5
NUM_DAYS = 7

product_ids = [f"P{i}" for i in range(1, NUM_PRODUCTS + 1)]

def generate_random_date(days_ago: int) -> str:
    """Generate a random date 'days_ago' days from now."""
    return (datetime.now() - timedelta(days=days_ago)).strftime("%Y-%m-%d")

def generate_random_sales_transaction() -> Dict[str, Any]:
    """Generate a random sales transaction."""
    product_id = random.choice(product_ids)
    quantity = random.randint(1, 10)
    revenue = random.randint(20, 200)
    return {"ProductID": product_id, "Quantity": quantity, "Revenue": revenue}

def generate_store_sales_data() -> Dict[str, List[Dict[str, Any]]]:
    """Generate sales data for a store across multiple days."""
    store_sales = {}
    for day in range(NUM_DAYS):
        date = generate_random_date(day)
        day_sales = [generate_random_sales_transaction() for _ in range(random.randint(10, 50))]
        store_sales[date] = day_sales
    return store_sales

def generate_all_stores_data() -> Dict[str, Dict[str, List[Dict[str, Any]]]]:
    """Generate sales data for all stores."""
    all_stores_sales= {}
    for store_id in range(1, NUM_STORES + 1):
        store_sales = generate_store_sales_data()
        all_stores_sales[f"Store{store_id}"] = store_sales
    return all_stores_sales

all_stores_sales = generate_all_stores_data()

# %%
all_stores_sales
# Out:
# {'Store1': {'2023-08-22': [{'ProductID': 'P4', 'Quantity': 9, 'Revenue': 133},
#    {'ProductID': 'P1', 'Quantity': 5, 'Revenue': 131},
#    {'ProductID': 'P4', 'Quantity': 2, 'Revenue': 60},
#    {'ProductID': 'P2', 'Quantity': 7, 'Revenue': 135},
#    {'ProductID': 'P3', 'Quantity': 9, 'Revenue': 141},
#    {'ProductID': 'P4', 'Quantity': 3, 'Revenue': 86},
#    {'ProductID': 'P1', 'Quantity': 8, 'Revenue': 123},
#    {'ProductID': 'P1', 'Quantity': 1, 'Revenue': 103},
#    {'ProductID': 'P1', 'Quantity': 8, 'Revenue': 74},
#    {'ProductID': 'P1', 'Quantity': 4, 'Revenue': 59},
#    {'ProductID': 'P3', 'Quantity': 3, 'Revenue': 66},
#    {'ProductID': 'P5', 'Quantity': 1, 'Revenue': 70},
#    {'ProductID': 'P4', 'Quantity': 4, 'Revenue': 42},
#    {'ProductID': 'P5', 'Quantity': 4, 'Revenue': 27},
#    {'ProductID': 'P2', 'Quantity': 5, 'Revenue': 156},
#    {'ProductID': 'P4', 'Quantity': 5, 'Revenue': 21},
#    {'ProductID': 'P1', 'Quantity': 4, 'Revenue': 139},
#    {'ProductID': 'P3', 'Quantity': 4, 'Revenue': 176},
#    {'ProductID': 'P2', 'Quantity': 5, 'Revenue': 94}],
#   '2023-08-21': [{'ProductID': 'P5', 'Quantity': 2, 'Revenue': 132},
#    {'ProductID': 'P2', 'Quantity': 8, 'Revenue': 159},
#    {'ProductID': 'P1', 'Quantity': 7, 'Revenue': 36},
#    {'ProductID': 'P4', 'Quantity': 3, 'Revenue': 146},
#    {'ProductID': 'P5', 'Quantity': 4, 'Revenue': 198},
#    {'ProductID': 'P3', 'Quantity': 1, 'Revenue': 146},
#    {'ProductID': 'P1', 'Quantity': 2, 'Revenue': 109},
#    {'ProductID': 'P4', 'Quantity': 10, 'Revenue': 80},
#    {'ProductID': 'P1', 'Quantity': 9, 'Revenue': 186},
#    {'ProductID': 'P5', 'Quantity': 10, 'Revenue': 148},
#    {'ProductID': 'P1', 'Quantity': 2, 'Revenue': 27}],
#   '2023-08-20': [{'ProductID': 'P2', 'Quantity': 2, 'Revenue': 33},
#    {'ProductID': 'P3', 'Quantity': 5, 'Revenue': 82},
#    {'ProductID': 'P3', 'Quantity': 7, 'Revenue': 60},
#    {'ProductID': 'P5', 'Quantity': 6, 'Revenue': 172},
#    {'ProductID': 'P3', 'Quantity': 7, 'Revenue': 177},
#    {'ProductID': 'P1', 'Quantity': 3, 'Revenue': 77},
#    {'ProductID': 'P5', 'Quantity': 9, 'Revenue': 62},
#    {'ProductID': 'P5', 'Quantity': 7, 'Revenue': 103},
#    {'ProductID': 'P2', 'Quantity': 6, 'Revenue': 26},
#    {'ProductID': 'P5', 'Quantity': 5, 'Revenue': 136},
#    {'ProductID': 'P1', 'Quantity': 2, 'Revenue': 103},
#    {'ProductID': 'P3', 'Quantity': 2, 'Revenue': 109},
#    {'ProductID': 'P5', 'Quantity': 10, 'Revenue': 136},
#    {'ProductID': 'P3', 'Quantity': 8, 'Revenue': 130},
#    {'ProductID': 'P2', 'Quantity': 4, 'Revenue': 150},
#    {'ProductID': 'P4', 'Quantity': 8, 'Revenue': 56},
#    {'ProductID': 'P2', 'Quantity': 1, 'Revenue': 120},
#    {'ProductID': 'P4', 'Quantity': 2, 'Revenue': 71},
#    {'ProductID': 'P5', 'Quantity': 8, 'Revenue': 195},
#    {'ProductID': 'P4', 'Quantity': 7, 'Revenue': 195},
#    {'ProductID': 'P3', 'Quantity': 9, 'Revenue': 96},
#    {'ProductID': 'P2', 'Quantity': 9, 'Revenue': 135},
#    {'ProductID': 'P1', 'Quantity': 6, 'Revenue': 54},
#    {'ProductID': 'P5', 'Quantity': 3, 'Revenue': 164},
#    {'ProductID': 'P2', 'Quantity': 5, 'Revenue': 47},
#    {'ProductID': 'P1', 'Quantity': 4, 'Revenue': 37},
#    {'ProductID': 'P2', 'Quantity': 7, 'Revenue': 95},
#    {'ProductID': 'P5', 'Quantity': 7, 'Revenue': 22},
#    {'ProductID': 'P2', 'Quantity': 10, 'Revenue': 44},
#    {'ProductID': 'P1', 'Quantity': 7, 'Revenue': 146},
#    {'ProductID': 'P4', 'Quantity': 9, 'Revenue': 190},
#    {'ProductID': 'P3', 'Quantity': 4, 'Revenue': 127},
#    {'ProductID': 'P3', 'Quantity': 7, 'Revenue': 198},
#    {'ProductID': 'P4', 'Quantity': 6, 'Revenue': 166},
#    {'ProductID': 'P4', 'Quantity': 3, 'Revenue': 151},
#    {'ProductID': 'P4', 'Quantity': 3, 'Revenue': 157},
#    {'ProductID': 'P2', 'Quantity': 6, 'Revenue': 140},
#    {'ProductID': 'P5', 'Quantity': 3, 'Revenue': 133},
#    {'ProductID': 'P1', 'Quantity': 5, 'Revenue': 108}],
#   '2023-08-19': [{'ProductID': 'P1', 'Quantity': 3, 'Revenue': 55},
#    {'ProductID': 'P1', 'Quantity': 4, 'Revenue': 77},
#    {'ProductID': 'P4', 'Quantity': 7, 'Revenue': 37},
#    {'ProductID': 'P4', 'Quantity': 1, 'Revenue': 147},
#    {'ProductID': 'P5', 'Quantity': 2, 'Revenue': 199},
#    {'ProductID': 'P4', 'Quantity': 6, 'Revenue': 26},
#    {'ProductID': 'P3', 'Quantity': 1, 'Revenue': 20},
#    {'ProductID': 'P4', 'Quantity': 7, 'Revenue': 79},
#    {'ProductID': 'P1', 'Quantity': 7, 'Revenue': 137},
#    {'ProductID': 'P2', 'Quantity': 8, 'Revenue': 79},
#    {'ProductID': 'P1', 'Quantity': 4, 'Revenue': 120},
#    {'ProductID': 'P4', 'Quantity': 2, 'Revenue': 178},
#    {'ProductID': 'P5', 'Quantity': 6, 'Revenue': 71},
#    {'ProductID': 'P1', 'Quantity': 1, 'Revenue': 41},
#    {'ProductID': 'P3', 'Quantity': 7, 'Revenue': 127},
#    {'ProductID': 'P1', 'Quantity': 5, 'Revenue': 21},
#    {'ProductID': 'P3', 'Quantity': 8, 'Revenue': 75},
#    {'ProductID': 'P5', 'Quantity': 5, 'Revenue': 150},
#    {'ProductID': 'P3', 'Quantity': 3, 'Revenue': 82},
#    {'ProductID': 'P4', 'Quantity': 8, 'Revenue': 58},
#    {'ProductID': 'P4', 'Quantity': 8, 'Revenue': 161},
#    {'ProductID': 'P2', 'Quantity': 6, 'Revenue': 80},
#    {'ProductID': 'P3', 'Quantity': 8, 'Revenue': 190},
#    {'ProductID': 'P4', 'Quantity': 7, 'Revenue': 127},
#    {'ProductID': 'P3', 'Quantity': 2, 'Revenue': 200},
#    {'ProductID': 'P3', 'Quantity': 5, 'Revenue': 190},
#    {'ProductID': 'P3', 'Quantity': 7, 'Revenue': 107},
#    {'ProductID': 'P1', 'Quantity': 1, 'Revenue': 139},
#    {'ProductID': 'P2', 'Quantity': 7, 'Revenue': 25},
#    {'ProductID': 'P2', 'Quantity': 2, 'Revenue': 122}],
#   '2023-08-18': [{'ProductID': 'P1', 'Quantity': 3, 'Revenue': 25},
#    {'ProductID': 'P5', 'Quantity': 7, 'Revenue': 130},
#    {'ProductID': 'P2', 'Quantity': 2, 'Revenue': 118},
#    {'ProductID': 'P2', 'Quantity': 3, 'Revenue': 135},
#    {'ProductID': 'P2', 'Quantity': 9, 'Revenue': 89},
#    {'ProductID': 'P2', 'Quantity': 8, 'Revenue': 182},
#    {'ProductID': 'P2', 'Quantity': 3, 'Revenue': 42},
#    {'ProductID': 'P5', 'Quantity': 8, 'Revenue': 76},
#    {'ProductID': 'P4', 'Quantity': 10, 'Revenue': 146},
#    {'ProductID': 'P5', 'Quantity': 7, 'Revenue': 95},
#    {'ProductID': 'P1', 'Quantity': 4, 'Revenue': 27},
#    {'ProductID': 'P3', 'Quantity': 6, 'Revenue': 80},
#    {'ProductID': 'P3', 'Quantity': 8, 'Revenue': 198},
#    {'ProductID': 'P1', 'Quantity': 10, 'Revenue': 109},
#    {'ProductID': 'P3', 'Quantity': 9, 'Revenue': 192},
#    {'ProductID': 'P1', 'Quantity': 10, 'Revenue': 65},
#    {'ProductID': 'P5', 'Quantity': 7, 'Revenue': 22},
#    {'ProductID': 'P3', 'Quantity': 6, 'Revenue': 128},
#    {'ProductID': 'P3', 'Quantity': 5, 'Revenue': 91},
#    {'ProductID': 'P3', 'Quantity': 9, 'Revenue': 199},
#    {'ProductID': 'P5', 'Quantity': 9, 'Revenue': 173},
#    {'ProductID': 'P5', 'Quantity': 6, 'Revenue': 175},
#    {'ProductID': 'P2', 'Quantity': 8, 'Revenue': 99},
#    {'ProductID': 'P4', 'Quantity': 3, 'Revenue': 62},
#    {'ProductID': 'P2', 'Quantity': 10, 'Revenue': 74},
#    {'ProductID': 'P2', 'Quantity': 9, 'Revenue': 55},
#    {'ProductID': 'P5', 'Quantity': 4, 'Revenue': 58},
#    {'ProductID': 'P1', 'Quantity': 9, 'Revenue': 49},
#    {'ProductID': 'P3', 'Quantity': 8, 'Revenue': 188},
#    {'ProductID': 'P4', 'Quantity': 5, 'Revenue': 195},
#    {'ProductID': 'P1', 'Quantity': 5, 'Revenue': 185},
#    {'ProductID': 'P5', 'Quantity': 1, 'Revenue': 192},
#    {'ProductID': 'P1', 'Quantity': 7, 'Revenue': 152},
#    {'ProductID': 'P3', 'Quantity': 9, 'Revenue': 62},
#    {'ProductID': 'P4', 'Quantity': 1, 'Revenue': 119},
#    {'ProductID': 'P1', 'Quantity': 2, 'Revenue': 156},
#    {'ProductID': 'P1', 'Quantity': 5, 'Revenue': 127},
#    {'ProductID': 'P2', 'Quantity': 4, 'Revenue': 122},
#    {'ProductID': 'P5', 'Quantity': 3, 'Revenue': 95},
#    {'ProductID': 'P5', 'Quantity': 5, 'Revenue': 115},
#    {'ProductID': 'P2', 'Quantity': 5, 'Revenue': 83},
#    {'ProductID': 'P3', 'Quantity': 6, 'Revenue': 45},
#    {'ProductID': 'P5', 'Quantity': 7, 'Revenue':

#    {'ProductID': 'P3', 'Quantity': 5, 'Revenue': 154},
#    {'ProductID': 'P1', 'Quantity': 10, 'Revenue': 84},
#    {'ProductID': 'P2', 'Quantity': 5, 'Revenue': 45},
#    {'ProductID': 'P3', 'Quantity': 4, 'Revenue': 32},
#    {'ProductID': 'P3', 'Quantity': 7, 'Revenue': 119},
#    {'ProductID': 'P1', 'Quantity': 5, 'Revenue': 122},
#    {'ProductID': 'P1', 'Quantity': 6, 'Revenue': 182},
#    {'ProductID': 'P5', 'Quantity': 1, 'Revenue': 82},
#    {'ProductID': 'P1', 'Quantity': 8, 'Revenue': 137},
#    {'ProductID': 'P3', 'Quantity': 1, 'Revenue': 24},
#    {'ProductID': 'P1', 'Quantity': 1, 'Revenue': 124},
#    {'ProductID': 'P2', 'Quantity': 4, 'Revenue': 61},
#    {'ProductID': 'P3', 'Quantity': 4, 'Revenue': 182},
#    {'ProductID': 'P4', 'Quantity': 3, 'Revenue': 197},
#    {'ProductID': 'P2', 'Quantity': 3, 'Revenue': 56},
#    {'ProductID': 'P2', 'Quantity': 7, 'Revenue': 30},
#    {'ProductID': 'P1', 'Quantity': 10, 'Revenue': 35},
#    {'ProductID': 'P1', 'Quantity': 8, 'Revenue': 165},
#    {'ProductID': 'P1', 'Quantity': 6, 'Revenue': 175},
#    {'ProductID': 'P4', 'Quantity': 1, 'Revenue': 90},
#    {'ProductID': 'P5', 'Quantity': 8, 'Revenue': 25},
#    {'ProductID': 'P4', 'Quantity': 6, 'Revenue': 115},
#    {'ProductID': 'P2', 'Quantity': 1, 'Revenue': 107},
#    {'ProductID': 'P4', 'Quantity': 4, 'Revenue': 191},
#    {'ProductID': 'P3', 'Quantity': 6, 'Revenue': 80},
#    {'ProductID': 'P4', 'Quantity': 3, 'Revenue': 21},
#    {'ProductID': 'P1', 'Quantity': 8, 'Revenue': 105},
#    {'ProductID': 'P4', 'Quantity': 6, 'Revenue': 63},
#    {'ProductID': 'P4', 'Quantity': 8, 'Revenue': 59},
#    {'ProductID': 'P1', 'Quantity': 4, 'Revenue': 111}],
#   '2023-08-19': [{'ProductID': 'P4', 'Quantity': 7, 'Revenue': 29},
#    {'ProductID': 'P5', 'Quantity': 3, 'Revenue': 181},
#    {'ProductID': 'P2', 'Quantity': 4, 'Revenue': 85},
#    {'ProductID': 'P2', 'Quantity': 5, 'Revenue': 158},
#    {'ProductID': 'P1', 'Quantity': 8, 'Revenue': 114},
#    {'ProductID': 'P5', 'Quantity': 5, 'Revenue': 26},
#    {'ProductID': 'P1', 'Quantity': 9, 'Revenue': 167},
#    {'ProductID': 'P1', 'Quantity': 10, 'Revenue': 113},
#    {'ProductID': 'P2', 'Quantity': 1, 'Revenue': 196},
#    {'ProductID': 'P5', 'Quantity': 1, 'Revenue': 54},
#    {'ProductID': 'P2', 'Quantity': 7, 'Revenue': 123},
#    {'ProductID': 'P5', 'Quantity': 5, 'Revenue': 68},
#    {'ProductID': 'P2', 'Quantity': 6, 'Revenue': 69},
#    {'ProductID': 'P5', 'Quantity': 10, 'Revenue': 147},
#    {'ProductID': 'P1', 'Quantity': 8, 'Revenue': 194},
#    {'ProductID': 'P2', 'Quantity': 9, 'Revenue': 179},
#    {'ProductID': 'P4', 'Quantity': 1, 'Revenue': 75},
#    {'ProductID': 'P2', 'Quantity': 5, 'Revenue': 144},
#    {'ProductID': 'P2', 'Quantity': 6, 'Revenue': 117},
#    {'ProductID': 'P3', 'Quantity': 5, 'Revenue': 124}],
#   '2023-08-18': [{'ProductID': 'P4', 'Quantity': 7, 'Revenue': 140},
#    {'ProductID': 'P3', 'Quantity': 5, 'Revenue': 34},
#    {'ProductID': 'P3', 'Quantity': 8, 'Revenue': 64},
#    {'ProductID': 'P3', 'Quantity': 2, 'Revenue': 78},
#    {'ProductID': 'P2', 'Quantity': 3, 'Revenue': 170},
#    {'ProductID': 'P2', 'Quantity': 7, 'Revenue': 184},
#    {'ProductID': 'P2', 'Quantity': 8, 'Revenue': 176},
#    {'ProductID': 'P2', 'Quantity': 8, 'Revenue': 84},
#    {'ProductID': 'P1', 'Quantity': 7, 'Revenue': 55},
#    {'ProductID': 'P4', 'Quantity': 6, 'Revenue': 199}],
#   '2023-08-17': [{'ProductID': 'P5', 'Quantity': 9, 'Revenue': 130},
#    {'ProductID': 'P1', 'Quantity': 6, 'Revenue': 64},
#    {'ProductID': 'P3', 'Quantity': 9, 'Revenue': 26},
#    {'ProductID': 'P1', 'Quantity': 10, 'Revenue': 65},
#    {'ProductID': 'P2', 'Quantity': 2, 'Revenue': 30},
#    {'ProductID': 'P3', 'Quantity': 3, 'Revenue': 106},
#    {'ProductID': 'P4', 'Quantity': 7, 'Revenue': 194},
#    {'ProductID': 'P5', 'Quantity': 5, 'Revenue': 28},
#    {'ProductID': 'P3', 'Quantity': 9, 'Revenue': 125},
#    {'ProductID': 'P5', 'Quantity': 8, 'Revenue': 139},
#    {'ProductID': 'P5', 'Quantity': 3, 'Revenue': 34},
#    {'ProductID': 'P1', 'Quantity': 6, 'Revenue': 175},
#    {'ProductID': 'P2', 'Quantity': 5, 'Revenue': 44},
#    {'ProductID': 'P2', 'Quantity': 5, 'Revenue': 195},
#    {'ProductID': 'P5', 'Quantity': 8, 'Revenue': 157},
#    {'ProductID': 'P2', 'Quantity': 8, 'Revenue': 101},
#    {'ProductID': 'P5', 'Quantity': 10, 'Revenue': 63},
#    {'ProductID': 'P3', 'Quantity': 5, 'Revenue': 166},
#    {'ProductID': 'P3', 'Quantity': 1, 'Revenue': 124},
#    {'ProductID': 'P1', 'Quantity': 6, 'Revenue': 128},
#    {'ProductID': 'P5', 'Quantity': 3, 'Revenue': 130},
#    {'ProductID': 'P1', 'Quantity': 6, 'Revenue': 31},
#    {'ProductID': 'P4', 'Quantity': 1, 'Revenue': 191},
#    {'ProductID': 'P2', 'Quantity': 1, 'Revenue': 48},
#    {'ProductID': 'P4', 'Quantity': 5, 'Revenue': 90},
#    {'ProductID': 'P4', 'Quantity': 7, 'Revenue': 111},
#    {'ProductID': 'P2', 'Quantity': 2, 'Revenue': 85},
#    {'ProductID': 'P2', 'Quantity': 3, 'Revenue': 44},
#    {'ProductID': 'P2', 'Quantity': 5, 'Revenue': 155}],
#   '2023-08-16': [{'ProductID': 'P3', 'Quantity': 2, 'Revenue': 167},
#    {'ProductID': 'P5', 'Quantity': 6, 'Revenue': 124},
#    {'ProductID': 'P3', 'Quantity': 9, 'Revenue': 170},
#    {'ProductID': 'P1', 'Quantity': 2, 'Revenue': 47},
#    {'ProductID': 'P3', 'Quantity': 2, 'Revenue': 150},
#    {'ProductID': 'P1', 'Quantity': 7, 'Revenue': 52},
#    {'ProductID': 'P2', 'Quantity': 3, 'Revenue': 56},
#    {'ProductID': 'P2', 'Quantity': 6, 'Revenue': 100},
#    {'ProductID': 'P4', 'Quantity': 7, 'Revenue': 182},
#    {'ProductID': 'P1', 'Quantity': 3, 'Revenue': 40},
#    {'ProductID': 'P2', 'Quantity': 5, 'Revenue': 81},
#    {'ProductID': 'P3', 'Quantity': 10, 'Revenue': 73},
#    {'ProductID': 'P4', 'Quantity': 8, 'Revenue': 167},
#    {'ProductID': 'P3', 'Quantity': 8, 'Revenue': 145},
#    {'ProductID': 'P1', 'Quantity': 7, 'Revenue': 112},
#    {'ProductID': 'P2', 'Quantity': 4, 'Revenue': 70},
#    {'ProductID': 'P2', 'Quantity': 8, 'Revenue': 54},
#    {'ProductID': 'P3', 'Quantity': 7, 'Revenue': 145},
#    {'ProductID': 'P3', 'Quantity': 8, 'Revenue': 76},
#    {'ProductID': 'P4', 'Quantity': 3, 'Revenue': 44},
#    {'ProductID': 'P5', 'Quantity': 3, 'Revenue': 176},
#    {'ProductID': 'P1', 'Quantity': 1, 'Revenue': 59}]}}

# %%
# Calculate the total revenue for each store
store_total_revenues = {}
for store, sales_data in all_stores_sales.items():
    total_revenue = 0
    for day_sales in sales_data.values():
        for transaction in day_sales:
            total_revenue += transaction["Revenue"]
    store_total_revenues[store] = total_revenue

# %%
store_total_revenues[store]
# Out:
# 26161

# %%
# Calculate the total revenue for each product across all stores
product_total_revenues = {}
for store, sales_data in all_stores_sales.items():
    for day_sales in sales_data.values():
        for transaction in day_sales:
            product_id = transaction["ProductID"]
            revenue = transaction["Revenue"]
            if product_id not in product_total_revenues:
                product_total_revenues[product_id] = revenue
            else:
                product_total_revenues[product_id] += revenue

# %%
product_total_revenues[product_id]
# Out:
# 22429

# %%
# Identify the store with the highest total revenue
highest_revenue_store = max(store_total_revenues, key=store_total_revenues.get)

# %%
highest_revenue_store
# Out:
# 'Store2'

# %%
# Identify the product with the highest total revenue
highest_revenue_product = max(product_total_revenues, key=product_total_revenues.get)

# %%
highest_revenue_product
# Out:
# 'P5'

# %%
# Generate a report that summarizes the sales data
summary_report = f"Summary Report\n\n"
summary_report += "Total Revenue by Store:\n"
for store, total_revenue in store_total_revenues.items():
    summary_report += f"{store}: ${total_revenue}\n"
summary_report += f"\nStore with the Highest Total Revenue: {highest_revenue_store}\n\n"
summary_report += "Total Revenue by Product:\n"
for product, total_revenue in product_total_revenues.items():
    summary_report += f"{product}: ${total_revenue}\n"
summary_report += f"\nProduct with the Highest Total Revenue: {highest_revenue_product}\n"

print(summary_report)
# Out:
# Summary Report
#
# Total Revenue by Store:
# Store1: $19308
# Store2: $27750
# Store3: $19556
# Store4: $25040
# Store5: $26161
#
# Store with the Highest Total Revenue: Store2
#
# Total Revenue by Product:
# P5: $24148
# P4: $22429
# P2: $23727
# P1: $23400
# P3: $24111
#
# Product with the Highest Total Revenue: P5
